# %%
for col in df.columns[:5]:
    print(repr(col))
# Out:
# '___c___u___s___t___o___m___e___r_______i___d___'
# '___a___g___e___'
# '___g___e___n___d___e___r___'
# '___i___t___e___m_______p___u___r___c___h___a___s___e___d___'
# '___c___a___t___e___g___o___r___y___'

# %%
df.head()
# Out:
#    ___c___u___s___t___o___m___e___r_______i___d___  ___a___g___e___  \
# 0                                                1               55
# 1                                                2               19
# 2                                                3               50
# 3                                                4               21
# 4                                                5               45
#
#   ___g___e___n___d___e___r___  \
# 0                        Male
# 1                        Male
# 2                        Male
# 3                        Male
# 4                        Male
#
#   ___i___t___e___m_______p___u___r___c___h___a___s___e___d___  \
# 0                                             Blouse
# 1                                            Sweater
# 2                                              Jeans
# 3                                            Sandals
# 4                                             Blouse
#
#   ___c___a___t___e___g___o___r___y___  \
# 0                            Clothing
# 1                            Clothing
# 2                            Clothing
# 3                            Footwear
# 4                            Clothing
#
#    ___p___u___r___c___h___a___s___e_______a___m___o___u___n___t_______(___u___s___d___)___  \
# 0                                                 53
# 1                                                 64
# 2                                                 73
# 3                                                 90
# 4                                                 49
#
#   ___l___o___c___a___t___i___o___n___ ___s___i___z___e___  \
# 0                            Kentucky                   L
# 1                               Maine                   L
# 2                       Massachusetts                   S
# 3                        Rhode Island                   M
# 4                              Oregon                   M
#
#   ___c___o___l___o___r___ ___s___e___a___s___o___n___  \
# 0                    Gray                      Winter
# 1                  Maroon                      Winter
# 2                  Maroon                      Spring
# 3                  Maroon                      Spring
# 4               Turquoise                      Spring
#
#    ___r___e___v___i___e___w_______r___a___t___i___n___g___  \
# 0                                                3.1
# 1                                                3.1
# 2                                                3.1
# 3                                                3.5
# 4                                                2.7
#
#   ___s___u___b___s___c___r___i___p___t___i___o___n_______s___t___a___t___u___s___  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   ___s___h___i___p___p___i___n___g_______t___y___p___e___  \
# 0                                            Express
# 1                                            Express
# 2                                      Free Shipping
# 3                                       Next Day Air
# 4                                      Free Shipping
#
#   ___d___i___s___c___o___u___n___t_______a___p___p___l___i___e___d___  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   ___p___r___o___m___o_______c___o___d___e_______u___s___e___d___  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    ___p___r___e___v___i___o___u___s_______p___u___r___c___h___a___s___e___s___  \
# 0                                                 14
# 1                                                  2
# 2                                                 23
# 3                                                 49
# 4                                                 31
#
#   ___p___a___y___m___e___n___t_______m___e___t___h___o___d___  \
# 0                                              Venmo
# 1                                               Cash
# 2                                        Credit Card
# 3                                             PayPal
# 4                                             PayPal
#
#   ___f___r___e___q___u___e___n___c___y_______o___f_______p___u___r___c___h___a___s___e___s___
# 0                                        Fortnightly
# 1                                        Fortnightly
# 2                                             Weekly
# 3                                             Weekly
# 4                                           Annually

# %%
# Renaming columns according to snake casing for better readability and documentation

df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})
df.columns = df.columns.str.lower().str.replace(" ", "_")

df.to_sql("customer", con=engine, if_exists="replace", index=False)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_usd', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
labels = ['Young Adult', 'Adult', 'Middle-aged', 'Senior']

df['age_group'] = pd.qcut(df['Age'], q=4, labels=labels)

df[['Age', 'age_group']].head(10)
# Out:
#    Age    age_group
# 0   55  Middle-aged
# 1   19  Young Adult
# 2   50  Middle-aged
# 3   21  Young Adult
# 4   45  Middle-aged
# 5   46  Middle-aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middle-aged

# %%
frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['Frequency of Purchases'].map(frequency_mapping)
df[['purchase_frequency_days','Frequency of Purchases']].head(10)
# Out:
#    purchase_frequency_days Frequency of Purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually
# 5                        7                 Weekly
# 6                       90              Quarterly
# 7                        7                 Weekly
# 8                      365               Annually
# 9                       90              Quarterly

# %%
df[['Discount Applied','Promo Code Used']].head(10)
# Out:
#   Discount Applied Promo Code Used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
bool((df['Discount Applied'] == df['Promo Code Used']).all())
# Out:
# True

# %%
# Dropping promo code used column

df = df.drop('promo_code_used', axis=1)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases', 'age_group',
#        'purchase_frequency_days'],
#       dtype='object')

# %% [markdown]
# **Connect Jupyter Notebook to MySQL**

# %%
# !pip install pymysql sqlalchemy
# Out:
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: sqlalchemy in c:\users\nandana\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nandana\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nandana\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0

# %%
from sqlalchemy import create_engine

username = "root"
password = "YOUR_MYSQL_PASSWORD"
host = "localhost"
port = "3306"
database = "customer_behavior"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

# %%
df.to_csv("customer_cleaned.csv", index=False)

# %%
engine = create_engine("mysql+pymysql://datauser:1234@localhost/customer_behavior")

# %%
engine.connect()

# %%
df.to_sql(
    "customer",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 3900

# %%
df.to_sql("customer", con=engine, if_exists="replace", index=False)
# Out:
# 3900

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_").str.replace("(", "").str.replace(")", "")

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_usd', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SELECT COUNT(*) FROM customer"))
    print(result.fetchone())
# Out:
# (3900,)

# %%
df.to_sql("customer", con=engine, if_exists="replace", index=False)
# Out:
# 3900
